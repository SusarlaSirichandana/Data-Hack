# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
data=pd.read_csv('training_set_features.csv')

# %%
data
# Out:
#        respondent_id  xyz_concern  xyz_knowledge  behavioral_antiviral_meds  \
# 0                  0          1.0            0.0                        0.0
# 1                  1          3.0            2.0                        0.0
# 2                  2          1.0            1.0                        0.0
# 3                  3          1.0            1.0                        0.0
# 4                  4          2.0            1.0                        0.0
# ...              ...          ...            ...                        ...
# 26702          26702          2.0            0.0                        0.0
# 26703          26703          1.0            2.0                        0.0
# 26704          26704          2.0            2.0                        0.0
# 26705          26705          1.0            1.0                        0.0
# 26706          26706          0.0            0.0                        0.0
#
# ...

# %%
data=data.drop('hhs_geo_region',axis=1)

# %%
data=data.drop('employment_industry',axis=1)

# %%
data=data.drop("employment_occupation",axis=1)

# %%
data
# Out:
#        respondent_id  xyz_concern  xyz_knowledge  behavioral_antiviral_meds  \
# 0                  0          1.0            0.0                        0.0
# 1                  1          3.0            2.0                        0.0
# 2                  2          1.0            1.0                        0.0
# 3                  3          1.0            1.0                        0.0
# 4                  4          2.0            1.0                        0.0
# ...              ...          ...            ...                        ...
# 26702          26702          2.0            0.0                        0.0
# 26703          26703          1.0            2.0                        0.0
# 26704          26704          2.0            2.0                        0.0
# 26705          26705          1.0            1.0                        0.0
# 26706          26706          0.0            0.0                        0.0
#
# ...

# %%
data1=data.copy()

# %%
print(data.isnull().values.sum())
# Out:
# 33962

# %%
data.set_index(['respondent_id'], inplace=True)

# %%
data
# Out:
#                xyz_concern  xyz_knowledge  behavioral_antiviral_meds  \
# respondent_id
# 0                      1.0            0.0                        0.0
# 1                      3.0            2.0                        0.0
# 2                      1.0            1.0                        0.0
# 3                      1.0            1.0                        0.0
# 4                      2.0            1.0                        0.0
# ...                    ...            ...                        ...
# 26702                  2.0            0.0                        0.0
# 26703                  1.0            2.0                        0.0
# 26704                  2.0            2.0                        0.0
# 26705                  1.0            1.0                        0.0
# 26706                  0.0            0.0                        0.0
#
#                behavioral_avoidance  behavioral_face_mask  \
# respondent_id
# ...

# %%
x=data.iloc[:,:]

# %%
y1=data.iloc[:,-1]
y1
# Out:
# respondent_id
# 0        0
# 1        1
# 2        0
# 3        1
# 4        0
#         ..
# 26702    0
# 26703    0
# 26704    1
# 26705    0
# 26706    0
# Name: seasonal_vaccine, Length: 26707, dtype: int64

# %%
y2=data.iloc[:,-2]
y2
# Out:
# respondent_id
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 26702    0
# 26703    0
# 26704    0
# 26705    0
# 26706    0
# Name: xyz_vaccine, Length: 26707, dtype: int64

# %%
x
# Out:
#                xyz_concern  xyz_knowledge  behavioral_antiviral_meds  \
# respondent_id
# 0                      1.0            0.0                        0.0
# 1                      3.0            2.0                        0.0
# 2                      1.0            1.0                        0.0
# 3                      1.0            1.0                        0.0
# 4                      2.0            1.0                        0.0
# ...                    ...            ...                        ...
# 26702                  2.0            0.0                        0.0
# 26703                  1.0            2.0                        0.0
# 26704                  2.0            2.0                        0.0
# 26705                  1.0            1.0                        0.0
# 26706                  0.0            0.0                        0.0
#
#                behavioral_avoidance  behavioral_face_mask  \
# respondent_id
# ...

# %%
x.columns
# Out:
# Index(['xyz_concern', 'xyz_knowledge', 'behavioral_antiviral_meds',
#        'behavioral_avoidance', 'behavioral_face_mask', 'behavioral_wash_hands',
#        'behavioral_large_gatherings', 'behavioral_outside_home',
#        'behavioral_touch_face', 'doctor_recc_xyz', 'doctor_recc_seasonal',
#        'chronic_med_condition', 'child_under_6_months', 'health_worker',
#        'health_insurance', 'opinion_xyz_vacc_effective', 'opinion_xyz_risk',
#        'opinion_xyz_sick_from_vacc', 'opinion_seas_vacc_effective',
#        'opinion_seas_risk', 'opinion_seas_sick_from_vacc', 'age_group',
#        'education', 'race', 'sex', 'income_poverty', 'marital_status',
#        'rent_or_own', 'employment_status', 'census_msa', 'household_adults',
#        'household_children', 'xyz_vaccine', 'seasonal_vaccine'],
#       dtype='object')

# %%
from sklearn.impute import SimpleImputer
imputer=SimpleImputer(missing_values=np.nan,strategy='mean')

# %%
x=x.drop('xyz_vaccine',axis=1)

# %%
x=x.drop('seasonal_vaccine',axis=1)

# %%
x
# Out:
#                xyz_concern  xyz_knowledge  behavioral_antiviral_meds  \
# respondent_id
# 0                      1.0            0.0                        0.0
# 1                      3.0            2.0                        0.0
# 2                      1.0            1.0                        0.0
# 3                      1.0            1.0                        0.0
# 4                      2.0            1.0                        0.0
# ...                    ...            ...                        ...
# 26702                  2.0            0.0                        0.0
# 26703                  1.0            2.0                        0.0
# 26704                  2.0            2.0                        0.0
# 26705                  1.0            1.0                        0.0
# 26706                  0.0            0.0                        0.0
#
#                behavioral_avoidance  behavioral_face_mask  \
# respondent_id
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
x['rent_or_own']=le.fit_transform(x['rent_or_own'])

# %%
x['sex']=le.fit_transform(x['sex'])

# %%
x['marital_status']=le.fit_transform(x['marital_status'])

# %%
x['income_poverty']=le.fit_transform(x['income_poverty'])

# %%
x['census_msa']=le.fit_transform(x['census_msa'])

# %%
x.columns.tolist().index('employment_status')
# Out:
# 28

# %%
x['employment_status']=le.fit_transform(x['employment_status'])

# %%
x['race']=le.fit_transform(x['race'])

# %%
x['age_group']=le.fit_transform(x['age_group'])

# %%
x['education']=le.fit_transform(x['education'])

# %%
x.isnull().values.sum()
# Out:
# 23219

# %%
imputer.fit(x)
# Out:
# SimpleImputer()

# %%
x=imputer.transform(x)

# %%
x
# Out:
# array([[1., 0., 0., ..., 2., 0., 0.],
#        [3., 2., 0., ..., 0., 0., 0.],
#        [1., 1., 0., ..., 0., 2., 0.],
#        ...,
#        [2., 2., 0., ..., 0., 0., 0.],
#        [1., 1., 0., ..., 2., 1., 0.],
#        [0., 0., 0., ..., 1., 1., 0.]])

# %%
x_test=pd.read_csv('test_set_features.csv')

# %%
x_test
# Out:
#        respondent_id  xyz_concern  xyz_knowledge  behavioral_antiviral_meds  \
# 0              26707          2.0            2.0                        0.0
# 1              26708          1.0            1.0                        0.0
# 2              26709          2.0            2.0                        0.0
# 3              26710          1.0            1.0                        0.0
# 4              26711          3.0            1.0                        1.0
# ...              ...          ...            ...                        ...
# 26703          53410          1.0            1.0                        0.0
# 26704          53411          3.0            1.0                        0.0
# 26705          53412          0.0            1.0                        0.0
# 26706          53413          3.0            1.0                        0.0
# 26707          53414          2.0            1.0                        0.0
#
# ...

# %%
x_test.isnull().values.sum()
# Out:
# 60551

# %%
x_test=x_test.drop('hhs_geo_region',axis=1)

# %%
x_test=x_test.drop('employment_industry',axis=1)

# %%
x_test=x_test.drop('employment_occupation',axis=1)

# %%
x_test
# Out:
#        respondent_id  xyz_concern  xyz_knowledge  behavioral_antiviral_meds  \
# 0              26707          2.0            2.0                        0.0
# 1              26708          1.0            1.0                        0.0
# 2              26709          2.0            2.0                        0.0
# 3              26710          1.0            1.0                        0.0
# 4              26711          3.0            1.0                        1.0
# ...              ...          ...            ...                        ...
# 26703          53410          1.0            1.0                        0.0
# 26704          53411          3.0            1.0                        0.0
# 26705          53412          0.0            1.0                        0.0
# 26706          53413          3.0            1.0                        0.0
# 26707          53414          2.0            1.0                        0.0
#
# ...

# %%
x_test.set_index(['respondent_id'], inplace=True)

# %%
x_test
# Out:
#                xyz_concern  xyz_knowledge  behavioral_antiviral_meds  \
# respondent_id
# 26707                  2.0            2.0                        0.0
# 26708                  1.0            1.0                        0.0
# 26709                  2.0            2.0                        0.0
# 26710                  1.0            1.0                        0.0
# 26711                  3.0            1.0                        1.0
# ...                    ...            ...                        ...
# 53410                  1.0            1.0                        0.0
# 53411                  3.0            1.0                        0.0
# 53412                  0.0            1.0                        0.0
# 53413                  3.0            1.0                        0.0
# 53414                  2.0            1.0                        0.0
#
#                behavioral_avoidance  behavioral_face_mask  \
# respondent_id
# ...

# %%
x_test['rent_or_own']=le.fit_transform(x_test['rent_or_own'])

# %%
x_test['sex']=le.fit_transform(x_test['sex'])

# %%
x_test['age_group']=le.fit_transform(x_test['age_group'])

# %%
x_test['education']=le.fit_transform(x_test['education'])

# %%
x_test['race']=le.fit_transform(x_test['race'])

# %%
x_test['marital_status']=le.fit_transform(x_test['marital_status'])

# %%
x_test['employment_status']=le.fit_transform(x_test['employment_status'])

# %%
x_test['income_poverty']=le.fit_transform(x_test['income_poverty'])

# %%
x_test['census_msa']=le.fit_transform(x_test['census_msa'])

# %%
x_test['rent_or_own']=le.fit_transform(x_test['rent_or_own'])

# %%
x_test.columns
# Out:
# Index(['xyz_concern', 'xyz_knowledge', 'behavioral_antiviral_meds',
#        'behavioral_avoidance', 'behavioral_face_mask', 'behavioral_wash_hands',
#        'behavioral_large_gatherings', 'behavioral_outside_home',
#        'behavioral_touch_face', 'doctor_recc_xyz', 'doctor_recc_seasonal',
#        'chronic_med_condition', 'child_under_6_months', 'health_worker',
#        'health_insurance', 'opinion_xyz_vacc_effective', 'opinion_xyz_risk',
#        'opinion_xyz_sick_from_vacc', 'opinion_seas_vacc_effective',
#        'opinion_seas_risk', 'opinion_seas_sick_from_vacc', 'age_group',
#        'education', 'race', 'sex', 'income_poverty', 'marital_status',
#        'rent_or_own', 'employment_status', 'census_msa', 'household_adults',
#        'household_children'],
#       dtype='object')

# %%
x_test
# Out:
#                xyz_concern  xyz_knowledge  behavioral_antiviral_meds  \
# respondent_id
# 26707                  2.0            2.0                        0.0
# 26708                  1.0            1.0                        0.0
# 26709                  2.0            2.0                        0.0
# 26710                  1.0            1.0                        0.0
# 26711                  3.0            1.0                        1.0
# ...                    ...            ...                        ...
# 53410                  1.0            1.0                        0.0
# 53411                  3.0            1.0                        0.0
# 53412                  0.0            1.0                        0.0
# 53413                  3.0            1.0                        0.0
# 53414                  2.0            1.0                        0.0
#
#                behavioral_avoidance  behavioral_face_mask  \
# respondent_id
# ...

# %%
imputer.fit(x_test)
# Out:
# SimpleImputer()

# %%
x_test=imputer.transform(x_test)

# %%
x_test
# Out:
# array([[2., 2., 0., ..., 0., 1., 0.],
#        [1., 1., 0., ..., 2., 3., 0.],
#        [2., 2., 0., ..., 2., 1., 0.],
#        ...,
#        [0., 1., 0., ..., 0., 1., 0.],
#        [3., 1., 0., ..., 0., 1., 0.],
#        [2., 1., 0., ..., 1., 0., 0.]])

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
x=sc.fit_transform(x)

# %%
x
# Out:
# array([[-0.68060883, -2.04692846, -0.22691136, ...,  1.4168754 ,
#         -1.18217739, -0.57866659],
#        [ 1.5202786 ,  1.19564718, -0.22691136, ..., -1.01237871,
#         -1.18217739, -0.57866659],
#        [-0.68060883, -0.42564064, -0.22691136, ..., -1.01237871,
#          1.48489142, -0.57866659],
#        ...,
#        [ 0.41983489,  1.19564718, -0.22691136, ..., -1.01237871,
#         -1.18217739, -0.57866659],
#        [-0.68060883, -0.42564064, -0.22691136, ...,  1.4168754 ,
#          0.15135701, -0.57866659],
#        [-1.78105254, -2.04692846, -0.22691136, ...,  0.20224834,
#          0.15135701, -0.57866659]])

# %%
x_test=sc.fit_transform(x_test)

# %%
x_test
# Out:
# array([[ 0.41812342,  1.19498678, -0.22889624, ..., -0.99277669,
#          0.14072438, -0.58398583],
#        [-0.69138518, -0.43315438, -0.22889624, ...,  1.44438309,
#          2.80367814, -0.58398583],
#        [ 0.41812342,  1.19498678, -0.22889624, ...,  1.44438309,
#          0.14072438, -0.58398583],
#        ...,
#        [-1.80089377, -0.43315438, -0.22889624, ..., -0.99277669,
#          0.14072438, -0.58398583],
#        [ 1.52763201, -0.43315438, -0.22889624, ..., -0.99277669,
#          0.14072438, -0.58398583],
#        [ 0.41812342, -0.43315438, -0.22889624, ...,  0.2258032 ,
#         -1.1907525 , -0.58398583]])

# %%
from sklearn.linear_model import LogisticRegression
classifier=LogisticRegression()
classifier.fit(x,y1)
# Out:
# LogisticRegression()

# %%
y1_pred=classifier.predict_proba(x_test)

# %%
y1_pred
# Out:
# array([[0.76054352, 0.23945648],
#        [0.97035702, 0.02964298],
#        [0.3181623 , 0.6818377 ],
#        ...,
#        [0.74738425, 0.25261575],
#        [0.59483371, 0.40516629],
#        [0.40353469, 0.59646531]])

# %%
y1_pred=y1_pred[:,1]

# %%
y1_pred
# Out:
# array([0.23945648, 0.02964298, 0.6818377 , ..., 0.25261575, 0.40516629,
#        0.59646531])

# %%
classifier.fit(x,y2)
# Out:
# LogisticRegression()

# %%
y2_pred=classifier.predict_proba(x_test)

# %%
y2_pred
# Out:
# array([[0.91411791, 0.08588209],
#        [0.98107201, 0.01892799],
#        [0.56163636, 0.43836364],
#        ...,
#        [0.83636599, 0.16363401],
#        [0.94878908, 0.05121092],
#        [0.37292008, 0.62707992]])

# %%
y2_pred=y2_pred[:,1]

# %%
y2_pred
# Out:
# array([0.08588209, 0.01892799, 0.43836364, ..., 0.16363401, 0.05121092,
#        0.62707992])

# %%
y1_pred
# Out:
# array([0.23945648, 0.02964298, 0.6818377 , ..., 0.25261575, 0.40516629,
#        0.59646531])

# %%
from sklearn.svm import SVC
sv=SVC(kernel='linear',probability=True)

# %%
sv.fit(x,y1)
# Out:
# SVC(kernel='linear', probability=True)

# %%
y1_pre=sv.predict_proba(x_test)

# %%
y1_pre
# Out:
# array([[0.7778079 , 0.2221921 ],
#        [0.96517929, 0.03482071],
#        [0.32690921, 0.67309079],
#        ...,
#        [0.75494892, 0.24505108],
#        [0.57822977, 0.42177023],
#        [0.42613649, 0.57386351]])

# %%
y1_pre=y1_pre[:,1]

# %%
y1_pre
# Out:
# array([0.2221921 , 0.03482071, 0.67309079, ..., 0.24505108, 0.42177023,
#        0.57386351])

# %%
sv.fit(x,y2)
# Out:
# SVC(kernel='linear', probability=True)

# %%
y2_pre=sv.predict_proba(x_test)

# %%
y2_pre
# Out:
# array([[0.90906097, 0.09093903],
#        [0.98299804, 0.01700196],
#        [0.65441243, 0.34558757],
#        ...,
#        [0.83202936, 0.16797064],
#        [0.94251497, 0.05748503],
#        [0.3394344 , 0.6605656 ]])

# %%
y2_pre=y2_pre[:,1]

# %%
y2_pre
# Out:
# array([0.09093903, 0.01700196, 0.34558757, ..., 0.16797064, 0.05748503,
#        0.6605656 ])

# %%
from sklearn.svm import SVC
sv=SVC(kernel='rbf',probability=True)

# %%
sv.fit(x,y1)
# Out:
# SVC(probability=True)

# %%
y1_p=sv.predict_proba(x_test)

# %%
y1_p
# Out:
# array([[0.8265556 , 0.1734444 ],
#        [0.86683505, 0.13316495],
#        [0.27437663, 0.72562337],
#        ...,
#        [0.83164099, 0.16835901],
#        [0.54183501, 0.45816499],
#        [0.2601602 , 0.7398398 ]])

# %%
y1_p=y1_p[:,1]

# %%
sv.fit(x,y2)
# Out:
# SVC(probability=True)

# %%
y2_p=sv.predict_proba(x_test)

# %%
y2_p
# Out:
# array([[0.91548715, 0.08451285],
#        [0.86929836, 0.13070164],
#        [0.76309116, 0.23690884],
#        ...,
#        [0.87306509, 0.12693491],
#        [0.96815541, 0.03184459],
#        [0.42729257, 0.57270743]])

# %%
y2_p=y2_p[:,1]

# %%
y2_p
# Out:
# array([0.08451285, 0.13070164, 0.23690884, ..., 0.12693491, 0.03184459,
#        0.57270743])

# %%
from sklearn.naive_bayes import GaussianNB

# %%
gnb=GaussianNB()

# %%
gnb.fit(x,y1)
# Out:
# GaussianNB()

# %%
y1_predict=gnb.predict_proba(x_test)

# %%
y1_predict
# Out:
# array([[8.52318870e-01, 1.47681130e-01],
#        [9.99999961e-01, 3.87047996e-08],
#        [4.44586716e-03, 9.95554133e-01],
#        ...,
#        [9.90296426e-01, 9.70357445e-03],
#        [5.06861209e-01, 4.93138791e-01],
#        [9.23742260e-02, 9.07625774e-01]])

# %%
gnb.fit(x,y2)
# Out:
# GaussianNB()

# %%
y2_predict=gnb.predict_proba(x_test)

# %%
y2_predict
# Out:
# array([[9.84609215e-01, 1.53907848e-02],
#        [9.99997241e-01, 2.75949156e-06],
#        [2.76677546e-02, 9.72332245e-01],
#        ...,
#        [9.98417764e-01, 1.58223618e-03],
#        [9.41089439e-01, 5.89105610e-02],
#        [4.48323763e-01, 5.51676237e-01]])

# %%
y1_predict
# Out:
# array([[8.52318870e-01, 1.47681130e-01],
#        [9.99999961e-01, 3.87047996e-08],
#        [4.44586716e-03, 9.95554133e-01],
#        ...,
#        [9.90296426e-01, 9.70357445e-03],
#        [5.06861209e-01, 4.93138791e-01],
#        [9.23742260e-02, 9.07625774e-01]])

# %%
y1_pred
# Out:
# array([0.23945648, 0.02964298, 0.6818377 , ..., 0.25261575, 0.40516629,
#        0.59646531])

# %%
y1_pre
# Out:
# array([0.2221921 , 0.03482071, 0.67309079, ..., 0.24505108, 0.42177023,
#        0.57386351])

# %%
y1_p
# Out:
# array([0.1734444 , 0.13316495, 0.72562337, ..., 0.16835901, 0.45816499,
#        0.7398398 ])

# %%
y2_pred
# Out:
# array([0.08588209, 0.01892799, 0.43836364, ..., 0.16363401, 0.05121092,
#        0.62707992])

# %%
y2_pre
# Out:
# array([0.09093903, 0.01700196, 0.34558757, ..., 0.16797064, 0.05748503,
#        0.6605656 ])

# %%
y2_p
# Out:
# array([0.08451285, 0.13070164, 0.23690884, ..., 0.12693491, 0.03184459,
#        0.57270743])

# %%
y2_predict
# Out:
# array([[9.84609215e-01, 1.53907848e-02],
#        [9.99997241e-01, 2.75949156e-06],
#        [2.76677546e-02, 9.72332245e-01],
#        ...,
#        [9.98417764e-01, 1.58223618e-03],
#        [9.41089439e-01, 5.89105610e-02],
#        [4.48323763e-01, 5.51676237e-01]])

# %%
y1_predict
# Out:
# array([[8.52318870e-01, 1.47681130e-01],
#        [9.99999961e-01, 3.87047996e-08],
#        [4.44586716e-03, 9.95554133e-01],
#        ...,
#        [9.90296426e-01, 9.70357445e-03],
#        [5.06861209e-01, 4.93138791e-01],
#        [9.23742260e-02, 9.07625774e-01]])

# %%
vaccinations=pd.DataFrame(y1_pred,y2_pred)

# %%
vaccinations.to_csv('vaccination.csv')

# %%
y1_pred
# Out:
# array([0.23945648, 0.02964298, 0.6818377 , ..., 0.25261575, 0.40516629,
#        0.59646531])

# %%
y2_pred
# Out:
# array([0.08588209, 0.01892799, 0.43836364, ..., 0.16363401, 0.05121092,
#        0.62707992])
